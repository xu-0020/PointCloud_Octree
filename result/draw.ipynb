# %%
file_path = "FboundRVtime_HR.txt"
the_first = 1
time_list = []
count_list = []
try:
    with open(file_path, "r") as file:
        for line in file:
            if(the_first):
                the_first = 0
                continue
            # Process each line here
            line = line.strip()  # Example: Print each line
            index = line.index("Time cost =") + len("Time cost =")
            words = line[index:].split()
            time_list.append(float(words[0]))
            count_list.append(float(words[-2]))
except FileNotFoundError:
    print("File not found.")
import matplotlib.pyplot as plt

plt.plot(count_list,time_list,'s-',color = 'r',label="ATT-RLSTM")#s-:方形
plt.xlabel("Fixed Bound change time HRTree(time cost in microseconds)")#横坐标名字
plt.ylabel("accuracy")#纵坐标名字
plt.legend(loc = "best")#图例
plt.show()

# %%
file_path = "FtimeRVbound_HR.txt"
the_first = 1
time_list = []
count_list = []
try:
    with open(file_path, "r") as file:
        for line in file:
            if(the_first):
                the_first = 0
                continue
            # Process each line here
            line = line.strip()  # Example: Print each line
            index = line.index("Time cost =") + len("Time cost =")
            words = line[index:].split()
            time_list.append(float(words[0]))
            count_list.append(float(words[-2]))
except FileNotFoundError:
    print("File not found.")
import matplotlib.pyplot as plt

plt.plot(count_list,time_list,'s-',color = 'r',label="ATT-RLSTM")#s-:方形
plt.xlabel("Fixed Time change Bound HRTree(time cost in microseconds)")#横坐标名字
plt.ylabel("accuracy")#纵坐标名字
plt.legend(loc = "best")#图例
plt.show()

# %%
file_path = "RVbound_R.txt"
the_first = 1
time_list = []
count_list = []
try:
    with open(file_path, "r") as file:
        for line in file:
            if(the_first):
                the_first = 0
                continue
            # Process each line here
            line = line.strip()  # Example: Print each line
            index = line.index("Time cost =") + len("Time cost =")
            words = line[index:].split()
            time_list.append(float(words[0]))
            count_list.append(float(words[-2]))
except FileNotFoundError:
    print("File not found.")
import matplotlib.pyplot as plt

plt.plot(count_list,time_list,'s-',color = 'r',label="ATT-RLSTM")#s-:方形
plt.xlabel("change Bound RTree(time cost in microseconds)")#横坐标名字
plt.ylabel("accuracy")#纵坐标名字
plt.legend(loc = "best")#图例
plt.show()

# %%
file_path = "FtimeRVbound_RT.txt"
the_first = 1
time_list = []
count_list = []
try:
    with open(file_path, "r") as file:
        for line in file:
            if(the_first):
                the_first = 0
                continue
            # Process each line here
            line = line.strip()  # Example: Print each line
            index = line.index("Time cost =") + len("Time cost =")
            words = line[index:].split()
            time_list.append(float(words[0]))
            count_list.append(float(words[-2]))
except FileNotFoundError:
    print("File not found.")
import matplotlib.pyplot as plt

plt.plot(count_list,time_list,'s-',color = 'r',label="ATT-RLSTM")#s-:方形
plt.xlabel("Fixed Time change Bound RTreeT(time cost in microseconds)")#横坐标名字
plt.ylabel("accuracy")#纵坐标名字
plt.legend(loc = "best")#图例
plt.show()

# %%
file_path = "FboundRVtime_RT.txt"
the_first = 1
time_list = []
count_list = []
try:
    with open(file_path, "r") as file:
        for line in file:
            if(the_first):
                the_first = 0
                continue
            # Process each line here
            line = line.strip()  # Example: Print each line
            index = line.index("Time cost =") + len("Time cost =")
            words = line[index:].split()
            time_list.append(float(words[0]))
            count_list.append(float(words[-2]))
except FileNotFoundError:
    print("File not found.")
import matplotlib.pyplot as plt

plt.plot(count_list,time_list,'s-',color = 'r',label="ATT-RLSTM")#s-:方形
plt.xlabel("Fixed Bound change Time RTreeT(time cost in microseconds)")#横坐标名字
plt.ylabel("accuracy")#纵坐标名字
plt.legend(loc = "best")#图例
plt.show()
